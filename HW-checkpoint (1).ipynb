# %%
# Question 1

import pandas as pd

# Load the dataset
url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
df = pd.read_csv(url)

# Display first few rows of the dataframe
print(df.head())

# Check for missing values
missing_values = df.isnull().sum()
print("\nMissing values in each column:")
print(missing_values)

# Summary: In this chat, you've asked for:A way to check for missing values in a CSV dataset using Pandas. You provided the URL to a Pokémon dataset hosted on GitHub.
# https://chatgpt.com/share/66e3672a-a8f0-8004-82e3-57924134a45d
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#
# Missing values in each column:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# ...

# %%
# Question 2
import pandas as pd

# Load the dataset
url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
df = pd.read_csv(url)

# Display column names
print("Columns in the dataset:")
print(df.columns)

# Display the number of rows and columns (data size)
print("\nDataset shape (rows, columns):")
print(df.shape)

# Observation: Each row of this dataset, which records the measurements for a specific data item, represent a observation. 
# Variable: Each column of this dataset, which captures different properties of each data item, represent a variable.

# Summary (line 1): Dataset Overview: You asked how to determine what columns (variables) the dataset contains and how many rows (observations) are in it. I provided code to display the column names and the shape of the dataset, which reveals the number of rows and columns.
# Summary (line 2): Defining Observations and Variables: You requested definitions for "observations" and "variables" in the context of your dataset. I explained that observations are the rows (representing individual Pokémon) and variables are the columns (representing attributes such as "HP", "Attack", etc.).
#https://chatgpt.com/share/66e3672a-a8f0-8004-82e3-57924134a45d
# Out:
# Columns in the dataset:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')
#
# Dataset shape (rows, columns):
# (800, 12)

# %%
# Question 3

import pandas as pd

# Load the dataset
url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
df = pd.read_csv(url)

# Get summary statistics for numerical columns
print("Summary statistics for numerical columns:")
print(df.describe())

# Count the number of Pokémon for each primary type
print("Count of Pokémon by Type 1:")
print(df['Type 1'].value_counts())

#The df.describe() function summaries the statistics for numerical data and the df['column'].value_counts function summaries the statistics for categorical data. For example,the code above the number of "Type 1" Pokemon.
# Summary (line 1): df.describe(): You asked how to get a statistical summary of the dataset. I provided code to show how to use df.describe() to get summary statistics of the numerical columns.
# Summary (line 2): df['column'].value_counts(): You wanted to know how to count unique values in a column. I gave an example using df['Type 1'].value_counts() to count how many Pokémon belong to each primary type.
# https://chatgpt.com/share/66e3672a-a8f0-8004-82e3-57924134a45d
# Out:
# Summary statistics for numerical columns:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# ...

# %%
# Question 4

import pandas as pd
import numpy as np

# Example dataset with both numeric and non-numeric variables and some missing values
data = {
    'Name': ['Bulbasaur', 'Ivysaur', 'Venusaur', 'Charmander', 'Charmeleon'],
    'Type 1': ['Grass', 'Grass', 'Grass', 'Fire', 'Fire'],
    'HP': [45, 60, np.nan, 39, np.nan],
    'Attack': [49, 62, 82, 52, np.nan],
    'Defense': [49, 63, 83, np.nan, 58]
}

# Creating DataFrame
df = pd.DataFrame(data)

# Displaying the full dataset
print("Full dataset:")
print(df)

# Showing the shape of the dataset (number of rows and columns)
print("\nShape of the dataset (rows, columns):")
print(df.shape)

# Showing summary statistics for numeric columns
print("\nSummary statistics for numeric columns (df.describe()):")
print(df.describe())

# Showing the count of unique values in the 'Type 1' column (non-numeric variable)
print("\nCount of unique values in 'Type 1' (non-numeric variable):")
print(df['Type 1'].value_counts())

# Explaination: the df.shape function reports the total number of rows containing columns with both numeric and non-numeric variables, while the df.describe() function only counts the numerical columns. In terms of missing value, df.shape counts the total number of rows for the column and df.describe() excludes the rows with missing number.
# Summary (line 1): Explaining Discrepancies: You asked why there might be differences between the number of columns in df.shape and df.describe(). I explained how df.describe() only analyzes numeric columns and how missing values affect the "count" column in its output.
# Summary (line 2): Example Code for Discrepancies: You asked for code that shows these discrepancies, and I provided an example that demonstrates the difference between the full dataset size (df.shape), the numeric column analysis (df.describe()), and how to count unique values in non-numeric columns.
# https://chatgpt.com/share/66e3672a-a8f0-8004-82e3-57924134a45d
# Out:
# Full dataset:
#          Name Type 1    HP  Attack  Defense
# 0   Bulbasaur  Grass  45.0    49.0     49.0
# 1     Ivysaur  Grass  60.0    62.0     63.0
# 2    Venusaur  Grass   NaN    82.0     83.0
# 3  Charmander   Fire  39.0    52.0      NaN
# 4  Charmeleon   Fire   NaN     NaN     58.0
#
# Shape of the dataset (rows, columns):
# (5, 5)
#
# Summary statistics for numeric columns (df.describe()):
#               HP     Attack    Defense
# count   3.000000   4.000000   4.000000
# mean   48.000000  61.250000  63.250000
# std    10.816654  14.908052  14.384598
# min    39.000000  49.000000  49.000000
# 25%    42.000000  51.250000  55.750000
# 50%    45.000000  57.000000  60.500000
# 75%    52.500000  67.000000  68.000000
# max    60.000000  82.000000  83.000000
#
# Count of unique values in 'Type 1' (non-numeric variable):
# Type 1
# Grass    3
# Fire     2
# Name: count, dtype: int64

# %%
# Question 5

# An "attribute", such as df.shape, describes facts about a dataset and presents stored value without performing any computation. For example, when you ask for the size of a dataset.
# A "method", such as df.describe(), is a function that performs actions which can be operated with the dataset and requires parentheses. For example, when you ask for calculating the standard deviation.
# Metaphorically, an "attribute" of a person can be characteristics like name, age and look, while a "method" would be things that this person can do.
# Summary: You asked for a clarification on the difference between an "attribute" (like df.shape) and a "method" (like df.describe()), and I explained the distinction between them in both technical and simpler terms.
# https://chatgpt.com/share/66e3672a-a8f0-8004-82e3-57924134a45d

# %%
# Question 6

# count: shows how many values are present, ignoring the missing values
# mean: presents the average valune of the non-missing values
# std: standard deviation, measures the spread of the values
# min: the minimum value
# 25%: the 25th percentile value, also known as the first quartile (Q1). It’s the value below which 25% of the data falls.
# 50%: the 50th percentile value, also known as the median. It’s the middle value of the data.
# 75%: the 75th percentile value, also known as the third quartile (Q3). It’s the value below which 75% of the data falls.
# max: the maximum value 

# Summary: You requested example code and definitions for the summary statistics provided by df.describe(), including count, mean, std, min, 25%, 50%, 75%, and max. I provided code to calculate and display these statistics manually.
# https://chatgpt.com/share/66e3672a-a8f0-8004-82e3-57924134a45d

# %%
# Question 7.1

import pandas as pd
import numpy as np

# Sample DataFrame with missing values
data = {
    'Name': ['Bulbasaur', 'Ivysaur', 'Venusaur', 'Charmander', 'Charmeleon'],
    'HP': [45, 60, np.nan, 39, np.nan],
    'Attack': [49, 62, 82, 52, np.nan],
    'Defense': [49, 63, 83, np.nan, 58]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Remove rows with any missing values
df_cleaned = df.dropna()

print("\nDataFrame after dropna():")
print(df_cleaned)
# Out:
# Original DataFrame:
#          Name    HP  Attack  Defense
# 0   Bulbasaur  45.0    49.0     49.0
# 1     Ivysaur  60.0    62.0     63.0
# 2    Venusaur   NaN    82.0     83.0
# 3  Charmander  39.0    52.0      NaN
# 4  Charmeleon   NaN     NaN     58.0
#
# DataFrame after dropna():
#         Name    HP  Attack  Defense
# 0  Bulbasaur  45.0    49.0     49.0
# 1    Ivysaur  60.0    62.0     63.0

# %%
# Question 7.2

import pandas as pd

# Sample DataFrame with an unnecessary column
data = {
    'Name': ['Bulbasaur', 'Ivysaur', 'Venusaur', 'Charmander', 'Charmeleon'],
    'HP': [45, 60, 65, 39, 55],
    'Attack': [49, 62, 82, 52, 70],
    'Defense': [49, 63, 83, 55, 58]
}

df = pd.DataFrame(data)

print("Original DataFrame:")
print(df)

# Remove the 'Name' column
del df['Name']

print("\nDataFrame after del df['Name']:")
print(df)
# Out:
# Original DataFrame:
#          Name  HP  Attack  Defense
# 0   Bulbasaur  45      49       49
# 1     Ivysaur  60      62       63
# 2    Venusaur  65      82       83
# 3  Charmander  39      52       55
# 4  Charmeleon  55      70       58
#
# DataFrame after del df['Name']:
#    HP  Attack  Defense
# 0  45      49       49
# 1  60      62       63
# 2  65      82       83
# 3  39      52       55
# 4  55      70       58

# %%
# Question 7.3

# dropna() drops a entire row and del df['col'] drops a entire column from the dataset, which could both causes unnecessary loss of data or loss of important data.

# Question 7.4

import pandas as pd

# Load the dataset from the URL
url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
df = pd.read_csv(url)

# Print the original DataFrame
print("Original DataFrame:")
print(df.head())

# Remove the 'Type 2' column
del df['Type 2']

# Print the DataFrame after removing the 'Type 2' column
print("\nDataFrame after removing 'Type 2':")
print(df.head())

# According to the missing value check at the start there are only missing values for the "Type 2" column from the original dataset.
# Summary (line 1): Use Cases for df.dropna() vs. del df['col']:
# Summary (line 2): df.dropna(): Preferred for removing rows with missing values.
# Summary (line 3): del df['col']: Preferred for removing specific columns from the DataFrame.
# Summary (line 4): Example of Removing a Column: You requested code to remove the Type 2 column from the Pokémon dataset and print the DataFrame before and after the removal.
# https://chatgpt.com/share/66e3672a-a8f0-8004-82e3-57924134a45d
# Out:
# Original DataFrame:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
#
# DataFrame after removing 'Type 2':
#    #                   Name Type 1  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0  1              Bulbasaur  Grass  45      49       49       65       65
# ...

# %%
# Question 8.1

import pandas as pd

# Load the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)

# Group by 'class' and describe 'age'
result = df.groupby("class")["age"].describe()

print(result)
# Out:
#         count       mean        std   min   25%   50%   75%   max
# class
# First   186.0  38.233441  14.802856  0.92  27.0  37.0  49.0  80.0
# Second  173.0  29.877630  14.001077  0.67  23.0  29.0  36.0  70.0
# Third   355.0  25.140620  12.495398  0.42  18.0  24.0  32.0  74.0

# %%
#Question 8.1

import pandas as pd

# Load the Titanic dataset
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv"
df = pd.read_csv(url)

# Group by 'sex' and describe 'fare'
result = df.groupby("sex")["fare"].describe()

print(result)

# Explanation: df.groupby ("col1")[col2].describe() are used to computate the statistics for a numerical variable categorized by a non numerical variable. 
# Summary (line 1): You mentioned working on analyzing the Titanic dataset from seaborn, and you might need help with understanding code and analyses related to this dataset.
# Summary (line 2): You asked for a demonstration of how to use df.groupby("col1")["col2"].describe() with the Titanic dataset and an explanation of what this function does. I provided a detailed explanation and a code example to group the data by one column and describe another column.
# Summary (line 3): You requested to print the Titanic dataset. I provided code to load and display the first few rows of the dataset using pandas.
# https://chatgpt.com/share/66e3a3e0-e540-8004-8965-9a5b4cc812b2
# Out:
#         count       mean        std   min        25%   50%    75%       max
# sex
# female  314.0  44.479818  57.997698  6.75  12.071875  23.0  55.00  512.3292
# male    577.0  25.523893  43.138263  0.00   7.895800  10.5  26.55  512.3292

# %%
# Question 8.2

# Because of the grouping. The counts of df.describe() reflect the number of non-missing entries for each column in the entire DataFrame. If any column has missing values, the count will be less than the total number of rows. df.describe() provides the contents of each column without regard to any grouping. It puts all the data in the DataFrame together.
# df.groupby("col1")["col2"].describe() counts the number of non-missing values in each group defined by col1. This is relative to the condition of the grouping. df.groupby("col1")["col2"].describe() provides a separate summary for each grouping.

# %%
# Question 8.3

#A (NameError: name 'pd' is not defined): Chatgpt - https://chatgpt.com/share/66e3672a-a8f0-8004-82e3-57924134a45d
#A (NameError: name 'pd' is not defined): Google - https://www.statology.org/nameerror-name-pd-is-not-defined/
#A (NameError: name 'pd' is not defined): Chatgpt provided direct solution as it has record of previous information. Google, on the other hand, provided an example but with two possible solutions.

#B (HTTPError: HTTP Error 404: Not Found): Chatgpt - https://chatgpt.com/share/66e3a932-3100-8004-bbf5-1df81e1df870
#B (HTTPError: HTTP Error 404: Not Found): Google - https://rollbar.com/blog/python-httperror/
#B (HTTPError: HTTP Error 404: Not Found): This time chatgpt provided two direct solutions which both worked and Google provided insights on the causes and how to fix the issue.

#C (NameError: name 'DF' is not defined): Chatgpt - https://chatgpt.com/share/66e3a932-3100-8004-bbf5-1df81e1df870
#C (NameError: name 'DF' is not defined): Google - https://stackabuse.com/bytes/fixing-nameerror-name-df-pd-is-not-defined-in-python/
#C (NameError: name 'DF' is not defined): Chatgpt explained the source of error and provided a direct solution. Google did not provide a solution valid for this situtation, which I believe would be due to the fact that whether the letter is uppercase or lowecase doesn't matter that much in the google search box.

#D (SyntaxError: '(' was never closed): Chatgpt - https://chatgpt.com/share/66e3672a-a8f0-8004-82e3-57924134a45d
#D (SyntaxError: '(' was never closed): Google - https://www.google.ca/search?q=syntaxerror+%27%28%27+was+never+closed+python&sca_esv=fe8129afcdc2433e&sca_upv=1&ei=oa7jZp-nJq6qptQPxYup4A4&oq=SyntaxError%3A+%27%28%27+was+never+closed+p&gs_lp=&sclient=gws-wiz-serp
#D (SyntaxError: '(' was never closed): Chatgpt provided direct solution and further explained some common causes of unbalanced parentheses. Most search result available on Google are people posting their own code and asking for help to troubleshoot.

#E (AttributeError: 'DataFrame' object has no attribute 'group_by'): Chatgpt - https://chatgpt.com/share/66e3a932-3100-8004-bbf5-1df81e1df870
#E (AttributeError: 'DataFrame' object has no attribute 'group_by'): Google - https://www.reddit.com/r/learnpython/comments/80rrvr/pandas_attributeerror_dataframe_object_has_no/
#E (AttributeError: 'DataFrame' object has no attribute 'group_by'): Chatgpt directly provided the fixed version of the code. Reddit again appearred to be the top search result, this time, clear answer that addressed this issue is present in the comment.

#F (KeyError: 'Class'/KeyError: 'Column not found: Age'): Chatgpt - https://chatgpt.com/share/66e3a932-3100-8004-bbf5-1df81e1df870
#F (KeyError: 'Class'/KeyError: 'Column not found: Age'): Google - https://www.google.ca/search?q=KeyError%3A+%27Column+not+found%3A+%27&sca_esv=fe8129afcdc2433e&sca_upv=1&ei=17PjZp6xG-TaptQPi4WvQA&ved=0ahUKEwje-Ki3_76IAxVkrYkEHYvCCwgQ4dUDCA8&uact=5&oq=KeyError%3A+%27Column+not+found%3A+%27&gs_lp=Egxnd3Mtd2l6LXNlcnAiHktleUVycm9yOiAnQ29sdW1uIG5vdCBmb3VuZDogJzIKEAAYsAMY1gQYRzIKEAAYsAMY1gQYRzIKEAAYsAMY1gQYRzIKEAAYsAMY1gQYRzIKEAAYsAMY1gQYRzIKEAAYsAMY1gQYRzIKEAAYsAMY1gQYRzIKEAAYsAMY1gQYR0iTE1DsDlj-EHABeACQAQCYAQCgAQCqAQC4AQPIAQD4AQGYAgGgAguYAwCIBgGQBgiSBwExoAcA&sclient=gws-wiz-serp
#F (KeyError: 'Class'/KeyError: 'Column not found: Age'): Chatgpt provided direct solution based on previous record, but the error is too specific for Google search.

#G (SyntaxError: invalid syntax): Chatgpt - https://chatgpt.com/share/66e3a932-3100-8004-bbf5-1df81e1df870
#G (SyntaxError: invalid syntax): Google - https://www.pythonmorsels.com/syntaxerror-invalid-syntax/#:~:text=Causes%20of%20SyntaxError%3A%20invalid%20syntax&text=Missing%20opening%20or%20closing%20parentheses,keyword%20as%20a%20variable%20name
#G (SyntaxError: invalid syntax): The range of the error described is quite broad, so Chatgpt provided possible solution and hypothesis of potential sources of error. Same situation applies to Google. The correct solution was present for both platform as a part of the "common cause" list.

# %%
#Summary 1: Today, we explored the Pokémon dataset by checking for missing values and examining its columns and size, with code provided for loading and inspecting the data. I clarified the concepts of observations (rows) and variables (columns) and explained the difference between attributes (like df.shape) and methods (like df.describe()). We discussed summary statistics and I provided code to manually calculate metrics such as count, mean, standard deviation, min, and max. We also compared data cleaning techniques, highlighting when to use df.dropna() to remove rows with missing values versus del df['col'] to remove specific columns. I provided practical code examples for removing the Type 2 column and addressed errors like NameError and SyntaxError, offering corrected code and troubleshooting tips throughout our conversation. 
#https://chatgpt.com/share/66e3672a-a8f0-8004-82e3-57924134a45d
#Summary 2: Today, we worked on analyzing the Titanic dataset, starting with understanding how to use df.groupby("col1")["col2"].describe() to group data by one column and describe another. You encountered a 404 error when trying to load the dataset, and I suggested using an alternative URL or downloading the dataset locally. We also addressed a NameError due to using DF instead of df, an AttributeError from using the incorrect .group_by() method instead of .groupby(), and a KeyError caused by incorrect column names ('Class' instead of 'class', and 'Age' instead of 'age'). Finally, a SyntaxError was encountered, which I helped troubleshoot by ensuring correct syntax and formatting in the code.
#https://chatgpt.com/share/66e3a932-3100-8004-bbf5-1df81e1df870

# %%
# Somewhat
